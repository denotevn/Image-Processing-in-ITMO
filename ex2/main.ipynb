# %% [markdown]
# ### **Question 1**

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("/home/tuandinh/Desktop/Image Processing in ITMO/images/image_ex2.jpg")
image.shape
# Out:
# (4912, 7360, 3)

# %%
plt.imshow(image)

# %%
B,G,R = image[2469,3652]
print(R,',',G,',', B)
# Out:
# 126 , 62 , 88

# %% [markdown]
# ### **Question 2**

# %%
image1 = cv2.imread("/home/tuandinh/Desktop/Image Processing in ITMO/images/image_ex2_1.jpg")
img_rgb = cv2.cvtColor(image1,cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img = img_rgb[1800:2289, 2690:3339]
plt.imshow(img)
# Answer 199

# %% [markdown]
# ### **3. Question 3**

# %%
image_3 = cv2.imread("/home/tuandinh/Desktop/Image Processing in ITMO/images/image 2_3.jpg")
image_rgb = cv2.cvtColor(image_3, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
print(image_3.shape)
print(image_rgb.shape)
# Out:
# (2592, 3888, 3)
# (2592, 3888, 3)

# %%
size_original = image_3.shape
size_original
# width x height x channel
#Answer 1 = 1.5
# Out:
# (2592, 3888, 3)

# %%
# img_resized = cv2.resize(src=img, dsize=(new_width, new_height))
ratio = 1.5 # width/height
height = int(860/1.5)
print(height)
image_resize = cv2.resize(image_rgb, (860, height))
image_resize.shape
# Out:
# 573
# (573, 860, 3)

# %%
# save image
import os
path = "/home/tuandinh/Desktop/Image Processing in ITMO/images"
cv2.imwrite(os.path.join(path, "test.jpg"), image_resize)
# Out:
# True
